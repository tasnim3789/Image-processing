# %%
import cv2
import math
import numpy as np
import keras_ocr
import os

def midpoint(x1, y1, x2, y2):
    x_mid = int((x1 + x2) / 2)
    y_mid = int((y1 + y2) / 2)
    return (x_mid, y_mid)

def inpaint_text(img_path, pipeline):  # Pass the pipeline as an argument
    img = keras_ocr.tools.read(img_path) 
    prediction_groups = pipeline.recognize([img])
    
    mask = np.zeros(img.shape[:2], dtype="uint8")
    for box in prediction_groups[0]:
        x0, y0 = box[1][0]
        x1, y1 = box[1][1] 
        x2, y2 = box[1][2]
        x3, y3 = box[1][3]
        
        x_mid0, y_mid0 = midpoint(x1, y1, x2, y2)
        x_mid1, y_mid1 = midpoint(x0, y0, x3, y3)
        
        thickness = int(math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2))
        
        cv2.line(mask, (x_mid0, y_mid0), (x_mid1, y_mid1), 255, thickness)
    
    inpainted_img = cv2.inpaint(img, mask, 7, cv2.INPAINT_NS)
             
    return inpainted_img

def main():
    pipeline = keras_ocr.pipeline.Pipeline()


    input_dir = "D:\\Research Related Work\\large Dataset\\large dataset\\Xray disease\\Text Remove\\normal"# Directory containing input images
    output_dir =  "D:\\Research Related Work\\large Dataset\\large dataset\\Xray disease\\Text Remove\\NRR"# Directory to save preprocessed images

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        if filename.endswith(".jpeg") or filename.endswith(".jpg") or filename.endswith(".png"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            inpainted_image = inpaint_text(input_path, pipeline)  # Pass the pipeline as an argument
            
            cv2.imwrite(output_path, inpainted_image)
            
            print(f"Processed: {filename}")

if __name__ == '__main__':
    main()
# Out:
# Looking for C:\Users\DELL\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\DELL\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6009.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6010.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6011.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6012.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 2s 2s/step
# Processed: Normal-6013.png
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 330ms/step
# Processed: Normal-6014.png
# 1/1 [==============================] - 4s 4s/step
# Processed: Normal-6015.png
# 1/1 [==============================] - 4s 4s/step
# Processed: Normal-6016.png
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 172ms/step
# Processed: Normal-6017.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6018.png
# 1/1 [==============================] - 4s 4s/step
# Processed: Normal-6019.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 129ms/step
# Processed: Normal-6020.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 187ms/step
# Processed: Normal-6021.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 331ms/step
# Processed: Normal-6022.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 125ms/step
# Processed: Normal-6023.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 401ms/step
# Processed: Normal-6024.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6025.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6026.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6027.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6028.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 134ms/step
# Processed: Normal-6029.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 200ms/step
# Processed: Normal-6030.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 163ms/step
# Processed: Normal-6031.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6032.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6033.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 156ms/step
# Processed: Normal-6034.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6035.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 254ms/step
# Processed: Normal-6036.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6037.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6038.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6039.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6040.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6041.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 157ms/step
# Processed: Normal-6042.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 298ms/step
# Processed: Normal-6043.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 251ms/step
# Processed: Normal-6044.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6045.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 157ms/step
# Processed: Normal-6046.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6047.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6048.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 158ms/step
# Processed: Normal-6049.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 143ms/step
# Processed: Normal-6050.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6051.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 183ms/step
# Processed: Normal-6052.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6053.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6054.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6055.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6056.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 176ms/step
# Processed: Normal-6057.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 185ms/step
# Processed: Normal-6058.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 159ms/step
# Processed: Normal-6059.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 173ms/step
# Processed: Normal-6060.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6061.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 148ms/step
# Processed: Normal-6062.png
# 1/1 [==============================] - 8s 8s/step
# Processed: Normal-6063.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 158ms/step
# Processed: Normal-6064.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6065.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 148ms/step
# Processed: Normal-6066.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6067.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6068.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 236ms/step
# Processed: Normal-6069.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6070.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6071.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6072.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6073.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 175ms/step
# Processed: Normal-6074.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6075.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6076.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6077.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 301ms/step
# Processed: Normal-6078.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6079.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6080.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 167ms/step
# Processed: Normal-6081.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6082.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 191ms/step
# Processed: Normal-6083.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 159ms/step
# Processed: Normal-6084.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6085.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 190ms/step
# Processed: Normal-6086.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6087.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 268ms/step
# Processed: Normal-6088.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6089.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 240ms/step
# Processed: Normal-6090.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 142ms/step
# Processed: Normal-6091.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 215ms/step
# Processed: Normal-6092.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6093.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6094.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 249ms/step
# Processed: Normal-6095.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 145ms/step
# Processed: Normal-6096.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6097.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 172ms/step
# Processed: Normal-6098.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6099.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6100.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 159ms/step
# Processed: Normal-6101.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6102.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 142ms/step
# Processed: Normal-6103.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6104.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6105.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 143ms/step
# Processed: Normal-6106.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 236ms/step
# Processed: Normal-6107.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 266ms/step
# Processed: Normal-6108.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 1s 536ms/step
# Processed: Normal-6109.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6110.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 204ms/step
# Processed: Normal-6111.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6112.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 236ms/step
# Processed: Normal-6113.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 188ms/step
# Processed: Normal-6114.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 143ms/step
# Processed: Normal-6115.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 125ms/step
# Processed: Normal-6116.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6117.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 209ms/step
# Processed: Normal-6118.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 173ms/step
# Processed: Normal-6119.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6120.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6121.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6122.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6123.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6124.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6125.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 173ms/step
# Processed: Normal-6126.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 129ms/step
# Processed: Normal-6127.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 204ms/step
# Processed: Normal-6128.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6129.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6130.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6131.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 168ms/step
# Processed: Normal-6132.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 168ms/step
# Processed: Normal-6133.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6134.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6135.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 214ms/step
# Processed: Normal-6136.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6137.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 301ms/step
# Processed: Normal-6138.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6139.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 277ms/step
# Processed: Normal-6140.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 189ms/step
# Processed: Normal-6141.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6142.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 143ms/step
# Processed: Normal-6143.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 289ms/step
# Processed: Normal-6144.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6145.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6146.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6147.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 181ms/step
# Processed: Normal-6148.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 311ms/step
# Processed: Normal-6149.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6150.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6151.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 172ms/step
# Processed: Normal-6152.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 169ms/step
# Processed: Normal-6153.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6154.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6155.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6156.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6157.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 183ms/step
# Processed: Normal-6158.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 137ms/step
# Processed: Normal-6159.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6160.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6161.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6162.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6163.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6164.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 448ms/step
# Processed: Normal-6165.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 125ms/step
# Processed: Normal-6166.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6167.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 174ms/step
# Processed: Normal-6168.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6169.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 152ms/step
# Processed: Normal-6170.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 159ms/step
# Processed: Normal-6171.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 152ms/step
# Processed: Normal-6172.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 204ms/step
# Processed: Normal-6173.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6174.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 167ms/step
# Processed: Normal-6175.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 126ms/step
# Processed: Normal-6176.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6177.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 212ms/step
# Processed: Normal-6178.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6179.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 139ms/step
# Processed: Normal-6180.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6181.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 251ms/step
# Processed: Normal-6182.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 153ms/step
# Processed: Normal-6183.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6184.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 251ms/step
# Processed: Normal-6185.png
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 299ms/step
# Processed: Normal-6186.png
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 215ms/step
# Processed: Normal-6187.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6188.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 172ms/step
# Processed: Normal-6189.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6190.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 219ms/step
# Processed: Normal-6191.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6192.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6193.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 153ms/step
# Processed: Normal-6194.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6195.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6196.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6197.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 149ms/step
# Processed: Normal-6198.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6199.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 267ms/step
# Processed: Normal-6200.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6201.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 416ms/step
# Processed: Normal-6202.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 376ms/step
# Processed: Normal-6203.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6204.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6205.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 160ms/step
# Processed: Normal-6206.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6207.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 156ms/step
# Processed: Normal-6208.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6209.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6210.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6211.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6212.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 157ms/step
# Processed: Normal-6213.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6214.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6215.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6216.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 159ms/step
# Processed: Normal-6217.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 145ms/step
# Processed: Normal-6218.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 155ms/step
# Processed: Normal-6219.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 259ms/step
# Processed: Normal-6220.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 264ms/step
# Processed: Normal-6221.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 189ms/step
# Processed: Normal-6222.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 148ms/step
# Processed: Normal-6223.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 182ms/step
# Processed: Normal-6224.png
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 284ms/step
# Processed: Normal-6225.png
# 1/1 [==============================] - 9s 9s/step
# Processed: Normal-6226.png
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 0s 450ms/step
# Processed: Normal-6227.png
# 1/1 [==============================] - 8s 8s/step
# Processed: Normal-6228.png
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 433ms/step
# Processed: Normal-6229.png
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 297ms/step
# Processed: Normal-6230.png
# 1/1 [==============================] - 7s 7s/step
# Processed: Normal-6231.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6232.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 235ms/step
# Processed: Normal-6233.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6234.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 173ms/step
# Processed: Normal-6235.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 314ms/step
# Processed: Normal-6236.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 219ms/step
# Processed: Normal-6237.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6238.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 266ms/step
# Processed: Normal-6239.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6240.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6241.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6242.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 150ms/step
# Processed: Normal-6243.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 157ms/step
# Processed: Normal-6244.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 125ms/step
# Processed: Normal-6245.png
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 141ms/step
# Processed: Normal-6246.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6247.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6248.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6249.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6250.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6251.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6252.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 211ms/step
# Processed: Normal-6253.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6254.png
# 1/1 [==============================] - 6s 6s/step
# Processed: Normal-6255.png
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 166ms/step
# Processed: Normal-6256.png
# 1/1 [==============================] - 5s 5s/step
# Processed: Normal-6257.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      53             print(f"Processed: {filename}")
#      55 if __name__ == '__main__':
# ---> 56     main()
#
# Cell In[2], line 49, in main()
#      46 input_path = os.path.join(input_dir, filename)
#      47 output_path = os.path.join(output_dir, filename)
# ---> 49 inpainted_image = inpaint_text(input_path, pipeline)  # Pass the pipeline as an argument
#      51 cv2.imwrite(output_path, inpainted_image)
#      53 print(f"Processed: {filename}")
#
# Cell In[2], line 14, in inpaint_text(img_path, pipeline)
#      12 def inpaint_text(img_path, pipeline):  # Pass the pipeline as an argument
#      13     img = keras_ocr.tools.read(img_path)
# ---> 14     prediction_groups = pipeline.recognize([img])
#      16     mask = np.zeros(img.shape[:2], dtype="uint8")
#      17     for box in prediction_groups[0]:
#
# File ~\anaconda3\lib\site-packages\keras_ocr\pipeline.py:62, in Pipeline.recognize(self, images, detection_kwargs, recognition_kwargs)
#      60 if recognition_kwargs is None:
#      61     recognition_kwargs = {}
# ---> 62 box_groups = self.detector.detect(images=images, **detection_kwargs)
#      63 prediction_groups = self.recognizer.recognize_from_boxes(
#      64     images=images, box_groups=box_groups, **recognition_kwargs
#      65 )
#      66 box_groups = [
#      67     tools.adjust_boxes(boxes=boxes, boxes_format="boxes", scale=1 / scale)
#      68     if scale != 1
#      69     else boxes
#      70     for boxes, scale in zip(box_groups, scales)
#      71 ]
#
# File ~\anaconda3\lib\site-packages\keras_ocr\detection.py:780, in Detector.detect(self, images, detection_threshold, text_threshold, link_threshold, size_threshold, **kwargs)
#     755 """Recognize the text in a set of images.
#     756
#     757 Args:
#    (...)
#     776     size_threshold: The minimum area for a word.
#     777 """
#     778 images = [compute_input(tools.read(image)) for image in images]
#     779 boxes = getBoxes(
# --> 780     self.model.predict(np.array(images), **kwargs),
#     781     detection_threshold=detection_threshold,
#     782     text_threshold=text_threshold,
#     783     link_threshold=link_threshold,
#     784     size_threshold=size_threshold,
#     785 )
#     786 return boxes
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:2382, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2380 for step in data_handler.steps():
#    2381     callbacks.on_predict_batch_begin(step)
# -> 2382     tmp_batch_outputs = self.predict_function(iterator)
#    2383     if data_handler.should_sync:
#    2384         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
